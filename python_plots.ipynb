# %% [markdown]
# ## Plot 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# Categories
categories = ['Average', 'General', 'Biomed', 'Clinics', 'STEM', 'Programming', 'Social media', 'Law', 'Finance', 'Transport']

# Data for each model (placeholders, replace with actual values from the image)
vicuna_7b = [14.2, 18.0, 9.8, 9.5, 8.9, 4.6, 14.6, 5.1, 24.9, 8.9]
vicuna_13b = [13.9, 21.5, 19.6, 13.2, 6.9, 5.7, 9.0, 12.1, 21.7, 11.5]
chatgpt = [34.9, 51.0, 38.1, 25.3, 18.6, 11.6, 31.3, 16.3, 52.8, 23.2]
uniner_7b = [41.7, 53.2, 51.5, 28.2, 29.3, 27.7, 41.6, 20.6, 58.7, 21.7]
uniner_13b = [43.4, 54.2, 51.2, 32.6, 32.7, 30.5, 44.4, 19.4, 60.9, 23.2]

# X locations of the groups
ind = np.arange(len(categories))  
width = 0.15

fig, ax = plt.subplots(figsize=(10, 8))

# Plotting data
rects1 = ax.bar(ind - width*2, vicuna_7b, width, label='Vicuna-7B')
rects2 = ax.bar(ind - width, vicuna_13b, width, label='Vicuna-13B')
rects3 = ax.bar(ind, chatgpt, width, label='ChatGPT')
rects4 = ax.bar(ind + width, uniner_7b, width, label='UniNER-7B')
rects5 = ax.bar(ind + width*2, uniner_13b, width, label='UniNER-13B')

# Adding text for labels, title, and custom x-axis tick labels, etc.
ax.set_xlabel('Domains')
ax.set_ylabel('F1 (%)')
ax.set_title('F1 Score by Model and Domain')
ax.set_xticks(ind)
ax.set_xticklabels(categories)
ax.legend()

# Adding the text with the percentage values
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offs    et points",
                    ha='center', va='bottom')

# Call the function to add labels
autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)

plt.tight_layout()

plt.show()
# Out:
# Failed to start the Kernel.
#
# Traceback (most recent call last):
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 21, in <module>
#
#     from IPython.core.application import (  # type:ignore[attr-defined]
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/IPython/__init__.py", line 53, in <module>
#
#     from .terminal.embed import embed
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/IPython/terminal/embed.py", line 15, in <module>
#
#     from IPython.core.interactiveshell import DummyMod, InteractiveShell
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 73, in <module>
#
#     from IPython.core.history import HistoryManager
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/IPython/core/history.py", line 11, in <module>
#
#     import sqlite3
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/sqlite3/__init__.py", line 23, in <module>
#
#     from sqlite3.dbapi2 import *
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/sqlite3/dbapi2.py", line 27, in <module>
#
#     from _sqlite3 import *
#
# ImportError: dlopen(/Applications/miniconda3/envs/llm/lib/python3.8/lib-dynload/_sqlite3.cpython-38-darwin.so, 0x0002): Symbol not found: _sqlite3_enable_load_extension
#
#   Referenced from: <A9A9D1FE-FD2A-32A6-89C9-8D3C621CEC76> /Applications/miniconda3/envs/llm/lib/python3.8/lib-dynload/_sqlite3.cpython-38-darwin.so
#
#   Expected in:     <567CDD63-191D-36E4-959B-7DE47C7AFD7A> /usr/lib/libsqlite3.dylib.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Categories
categories = ['Average', 'General', 'Biomed', 'Clinics', 'STEM', 'Programming', 'Social media', 'Law', 'Finance', 'Transport']

# Data for each model (placeholders, replace with actual values from the image)
vicuna_7b = [14.2, 18.0, 9.8, 9.5, 8.9, 4.6, 14.6, 5.1, 24.9, 8.9]
vicuna_13b = [13.9, 21.5, 19.6, 13.2, 6.9, 5.7, 9.0, 12.1, 21.7, 11.5]
chatgpt = [34.9, 51.0, 38.1, 25.3, 18.6, 11.6, 31.3, 16.3, 52.8, 23.2]
uniner_7b = [41.7, 53.2, 51.5, 28.2, 29.3, 27.7, 41.6, 20.6, 58.7, 21.7]
uniner_13b = [43.4, 54.2, 51.2, 32.6, 32.7, 30.5, 44.4, 19.4, 60.9, 23.2]

# Y locations of the groups
ind = np.arange(len(categories))  
height = 0.15

fig, ax = plt.subplots(figsize=(10, 8))

# Plotting data
rects1 = ax.barh(ind - height*2, vicuna_7b, height, label='Vicuna-7B')
rects2 = ax.barh(ind - height, vicuna_13b, height, label='Vicuna-13B')
rects3 = ax.barh(ind, chatgpt, height, label='ChatGPT')
rects4 = ax.barh(ind + height, uniner_7b, height, label='UniNER-7B')
rects5 = ax.barh(ind + height*2, uniner_13b, height, label='UniNER-13B')

# Adding text for labels, title, and custom y-axis tick labels, etc.
ax.set_ylabel('Domains')
ax.set_xlabel('F1 (%)')
ax.set_title('F1 Score by Model and Domain')
ax.set_yticks(ind)
ax.set_yticklabels(categories)
ax.legend()

# Adding the text with the percentage values
def autolabel(rects):
    for rect in rects:
        width = rect.get_width()
        ax.annotate('{}'.format(width),
                    xy=(width, rect.get_y() + rect.get_height() / 2),
                    xytext=(3, 0),  # 3 points horizontal offset
                    textcoords="offset points",
                    ha='left', va='center')

# Call the function to add labels
autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)

plt.tight_layout()

plt.show()
# Out:
# Failed to start the Kernel.
#
# Traceback (most recent call last):
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 21, in <module>
#
#     from IPython.core.application import (  # type:ignore[attr-defined]
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/IPython/__init__.py", line 53, in <module>
#
#     from .terminal.embed import embed
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/IPython/terminal/embed.py", line 15, in <module>
#
#     from IPython.core.interactiveshell import DummyMod, InteractiveShell
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 73, in <module>
#
#     from IPython.core.history import HistoryManager
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/IPython/core/history.py", line 11, in <module>
#
#     import sqlite3
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/sqlite3/__init__.py", line 23, in <module>
#
#     from sqlite3.dbapi2 import *
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/sqlite3/dbapi2.py", line 27, in <module>
#
#     from _sqlite3 import *
#
# ImportError: dlopen(/Applications/miniconda3/envs/llm/lib/python3.8/lib-dynload/_sqlite3.cpython-38-darwin.so, 0x0002): Symbol not found: _sqlite3_enable_load_extension
#
#   Referenced from: <A9A9D1FE-FD2A-32A6-89C9-8D3C621CEC76> /Applications/miniconda3/envs/llm/lib/python3.8/lib-dynload/_sqlite3.cpython-38-darwin.so
#
#   Expected in:     <567CDD63-191D-36E4-959B-7DE47C7AFD7A> /usr/lib/libsqlite3.dylib.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Plot 2

# %%
# Out:
# Failed to start the Kernel.
#
# Traceback (most recent call last):
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#
#     return _run_code(code, main_globals, None,
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/runpy.py", line 87, in _run_code
#
#     exec(code, run_globals)
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/ipykernel_launcher.py", line 15, in <module>
#
#     from ipykernel import kernelapp as app
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 21, in <module>
#
#     from IPython.core.application import (  # type:ignore[attr-defined]
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/IPython/__init__.py", line 53, in <module>
#
#     from .terminal.embed import embed
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/IPython/terminal/embed.py", line 15, in <module>
#
#     from IPython.core.interactiveshell import DummyMod, InteractiveShell
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 73, in <module>
#
#     from IPython.core.history import HistoryManager
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/site-packages/IPython/core/history.py", line 11, in <module>
#
#     import sqlite3
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/sqlite3/__init__.py", line 23, in <module>
#
#     from sqlite3.dbapi2 import *
#
#   File "/Applications/miniconda3/envs/llm/lib/python3.8/sqlite3/dbapi2.py", line 27, in <module>
#
#     from _sqlite3 import *
#
# ImportError: dlopen(/Applications/miniconda3/envs/llm/lib/python3.8/lib-dynload/_sqlite3.cpython-38-darwin.so, 0x0002): Symbol not found: _sqlite3_enable_load_extension
#
#   Referenced from: <A9A9D1FE-FD2A-32A6-89C9-8D3C621CEC76> /Applications/miniconda3/envs/llm/lib/python3.8/lib-dynload/_sqlite3.cpython-38-darwin.so
#
#   Expected in:     <567CDD63-191D-36E4-959B-7DE47C7AFD7A> /usr/lib/libsqlite3.dylib.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
